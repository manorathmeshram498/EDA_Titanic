# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df = df.drop(columns= 'PassengerId')

# %%
df['Survived'].unique()
# Out:
# array([0, 1])

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df[['Survived','Pclass','Age','SibSp','Parch','Fare']].apply(pd.unique)
# Out:
# Survived                                               [0, 1]
# Pclass                                              [3, 1, 2]
# Age         [22.0, 38.0, 26.0, 35.0, nan, 54.0, 2.0, 27.0,...
# SibSp                                   [1, 0, 3, 4, 2, 5, 8]
# Parch                                   [0, 1, 2, 5, 3, 4, 6]
# Fare        [7.25, 71.2833, 7.925, 53.1, 8.05, 8.4583, 51....
# dtype: object

# %% [markdown]
# Graphs to find outlier

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.scatterplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.lineplot(data=df, x='Age', y='Survived', marker='o')

# Labels and formatting
plt.title("survived vs age")
plt.xlabel("Age")
plt.ylabel("Survived")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title("Fare Distribution by Class")
plt.show()

# %%
sns.boxplot(x='Embarked', y='Fare', data=df)
plt.title('Fare Distribution by Embarkation Port')
plt.show()

# %%
sns.violinplot(df['Age'],inner='point')
# Out:
# <Axes: ylabel='Age'>

# %%
sns.PairGrid(df).map(sns.scatterplot)

# %%
df.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>],
#        [<Axes: title={'center': 'Parch'}>,
#         <Axes: title={'center': 'Fare'}>]], dtype=object)

# %%
sns.histplot(data = df[df['Survived']==0], x = 'Age', kde = True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.barplot(data = df, x = "Pclass", y = "Sex")
# Out:
# <Axes: xlabel='Pclass', ylabel='Sex'>

# %%
#Task 1: Pclass, Survival data how many survived class wise, percentage display it
df_pclass_survival_1 = df[["Pclass", "Survived"]].groupby("Pclass").mean()

# %%
df_pclass_survival_1
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df_pclass_survival = df[["Pclass", "Survived"]].groupby("Pclass").mean().reset_index()

# %%
df_pclass_survival[["Survived"]] = df_pclass_survival[["Survived"]]*100
df_pclass_survival.rename(columns = {"Survived": "Survival in %"}, inplace = True)

# %%
sns.barplot(data = df_pclass_survival, x = "Pclass", y = "Survival in %")
# Out:
# <Axes: xlabel='Pclass', ylabel='Survival in %'>

# %%
df_gender_survival = df[["Sex", "Survived"]].groupby("Sex").mean().reset_index()
df_gender_survival
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
sns.barplot(data = df_gender_survival, x = 'Sex', y = 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
df.tail(20)
# Out:
#      Survived  Pclass                                              Name  \
# 871         1       1  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                          Carlsson, Mr. Frans Olof
# 873         0       3                       Vander Cruyssen, Mr. Victor
# 874         1       2             Abelson, Mrs. Samuel (Hannah Wizosky)
# 875         1       3                  Najib, Miss. Adele Kiamie "Jane"
# 876         0       3                     Gustafsson, Mr. Alfred Ossian
# 877         0       3                              Petroff, Mr. Nedelio
# 878         0       3                                Laleff, Mr. Kristo
# 879         1       1     Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880         1       2      Shelley, Mrs. William (Imanita Parrish Hall)
# 881         0       3                                Markun, Mr. Johann
# 882         0       3                      Dahlberg, Miss. Gerda Ulrika
# ...

# %%
# Task 1 for you, extract the salution of each person and give the count

# %%
df["Title"] = df["Name"].str.extract(' ([A-Za-z]+)\.')

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Ms            1
# Mme           1
# Don           1
# Lady          1
# Sir           1
# Capt          1
# Countess      1
# Jonkheer      1
# Name: count, dtype: int64

# %%
sns.barplot(y = 'Survived', x = 'Title', data = df)
# Out:
# <Axes: xlabel='Title', ylabel='Survived'>

# %%
def replace_title(row):
  title = row['Title']
  relevalnt_titles = ['Mr', 'Mrs', 'Miss', 'Master']

  if title in relevalnt_titles:
    return title
  else:
    return 'others'

# %%
df['Title'] = df.apply(replace_title, axis =1)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
sns.barplot(y = 'Survived', x = 'Title', data = df)
# Out:
# <Axes: xlabel='Title', ylabel='Survived'>

# %%
#Task 3 - Find out the average of miss, mrs, mr, master

# %%
df[df["Title"]=="Miss"]["Age"].mean()
# Out:
# np.float64(21.773972602739725)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df[df['Survived'] == 1], x='Title')
plt.title('Survivors by Title')
plt.xlabel('Title')
plt.ylabel('Number of Survivors')
# plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df[df['Survived'] == 0], x='Title')
plt.title('Survivors by Title')
plt.xlabel('Title')
plt.ylabel('Number of Survivors')
# plt.grid(axis='y', linestyle='--', alpha=0.4)
plt.show()

# %%
pd.crosstab(df['Title'], df['Sex'])
# Out:
# Sex     female  male
# Title
# Master       0    40
# Miss       182     0
# Mr           0   517
# Mrs        125     0
# others       7    20

# %%
sns.countplot(x='Survived', hue="Title", data= df,order=[1,0])
plt.xticks(range(2),['Made it','Deceased'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fad5a6199d0>,
# ...
#  [Text(0, 0, 'Made it'), Text(1, 0, 'Deceased')])

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
#Task 4 --- find out the relavant columns and find out how many members are there in family and and plot a graph of which category family survived most

df["Family"] = df["SibSp"] + df["Parch"]

# %%
df["Family"].value_counts()
# Out:
# Family
# 0     537
# 1     161
# 2     102
# 3      29
# 5      22
# 4      15
# 6      12
# 10      7
# 7       6
# Name: count, dtype: int64

# %%
sns.barplot(data = df[['Family', 'Survived']].groupby('Family').mean().reset_index(), x = 'Family', y = 'Survived')
# Out:
# <Axes: xlabel='Family', ylabel='Survived'>

# %%
pd.crosstab(df['Title'], df['Family'])
# Out:
# Family   0   1   2   3   4   5   6   7   10
# Title
# Master    0   3  15   4   2   9   3   3   1
# Miss    100  27  22  10   9   4   6   1   3
# Mr      397  68  35   6   1   5   1   1   3
# Mrs      20  59  27   9   3   4   2   1   0
# others   20   4   3   0   0   0   0   0   0

# %%
#Task which family class type are dominant

df[["Pclass", "Family"]].groupby("Pclass").mean()
# Out:
#           Family
# Pclass
# 1       0.773148
# 2       0.782609
# 3       1.008147

# %%
df[['Pclass', 'Family']].groupby('Pclass').mean()
# Out:
#           Family
# Pclass
# 1       0.773148
# 2       0.782609
# 3       1.008147

# %%
#Age Imputation

#Hint : combine sex, title and age group by on age and title and take a mean of it

age_ref = df[['Sex','Age','Title']].groupby(['Sex','Title']).mean().reset_index()

# %%
age_ref
# Out:
#       Sex   Title        Age
# 0  female    Miss  21.773973
# 1  female     Mrs  35.898148
# 2  female  others  32.857143
# 3    male  Master   4.574167
# 4    male      Mr  32.368090
# 5    male  others  45.894737

# %%
plt.figure(figsize = (10,8))
sns.histplot(data= df, x = 'Age', hue = 'Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# EDA 1 Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('share_market_data.csv')

# %%
df.head(10)
# Out:
#          Date        Open        High         Low       Close   Volume
# 0  2023-01-01  113.679617  248.630921  126.470308  207.428707  2435719
# 1  2023-01-02  179.691931  234.584483  125.343535  194.803971  1231791
# 2  2023-01-03  109.302199  228.509870  116.551345  203.665900  1483330
# 3  2023-01-04  130.885919  226.767140  103.783303  219.855502  2427768
# 4  2023-01-05  154.428326  203.135891  123.397025  158.149225  2060962
# 5  2023-01-06  138.910591  249.936788  142.916197  192.477915  1292289
# 6  2023-01-07  160.330504  226.354356  115.217935  176.006412  1943966
# 7  2023-01-08  175.229286  201.286843  106.895944  152.433895  2068225
# 8  2023-01-09  170.616906  240.836158  107.893009  160.991217  2110090
# 9  2023-01-10  127.294389  231.097292  126.640032  179.389120  2478851

# %%
df.describe()
# Out:
#              Open        High         Low       Close        Volume
# count  100.000000  100.000000  100.000000  100.000000  1.000000e+02
# mean   148.647676  223.566020  118.058514  184.662497  1.841486e+06
# std     28.781768   14.249554   17.379971   21.111706  4.500567e+05
# min    100.899582  200.266713   90.155599  150.594793  1.000902e+06
# 25%    124.803425  211.025952  103.440238  164.766333  1.478959e+06
# 50%    150.629823  224.851142  117.930767  185.480689  1.939917e+06
# 75%    174.508498  234.936005  132.071861  201.043854  2.254992e+06
# max    199.787581  249.936788  149.478497  219.978857  2.488993e+06

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df_c = df.drop(columns = 'Date')

# %%
df
# Out:
#           Date        Open        High         Low       Close   Volume
# 0   2023-01-01  113.679617  248.630921  126.470308  207.428707  2435719
# 1   2023-01-02  179.691931  234.584483  125.343535  194.803971  1231791
# 2   2023-01-03  109.302199  228.509870  116.551345  203.665900  1483330
# 3   2023-01-04  130.885919  226.767140  103.783303  219.855502  2427768
# 4   2023-01-05  154.428326  203.135891  123.397025  158.149225  2060962
# ..         ...         ...         ...         ...         ...      ...
# 95  2023-04-06  117.269463  229.929199  139.219546  216.909936  1634151
# 96  2023-04-07  106.013569  211.238783   99.401689  182.349945  1102932
# 97  2023-04-08  159.903247  247.106844  149.478497  215.952168  2028177
# 98  2023-04-09  149.705586  202.847022  103.660036  180.713524  1141295
# 99  2023-04-10  150.940283  224.472881  129.625490  200.515839  2360159
#
# [100 rows x 6 columns]

# %%
df_c
# Out:
#           Open        High         Low       Close   Volume
# 0   113.679617  248.630921  126.470308  207.428707  2435719
# 1   179.691931  234.584483  125.343535  194.803971  1231791
# 2   109.302199  228.509870  116.551345  203.665900  1483330
# 3   130.885919  226.767140  103.783303  219.855502  2427768
# 4   154.428326  203.135891  123.397025  158.149225  2060962
# ..         ...         ...         ...         ...      ...
# 95  117.269463  229.929199  139.219546  216.909936  1634151
# 96  106.013569  211.238783   99.401689  182.349945  1102932
# 97  159.903247  247.106844  149.478497  215.952168  2028177
# 98  149.705586  202.847022  103.660036  180.713524  1141295
# 99  150.940283  224.472881  129.625490  200.515839  2360159
#
# [100 rows x 5 columns]

# %%
df['priceChange'] = df['Close']- df['Open']
df['Close%Change'] = df['Close'].pct_change()*100

# %%
df
# Out:
#           Date        Open        High         Low       Close   Volume  \
# 0   2023-01-01  113.679617  248.630921  126.470308  207.428707  2435719
# 1   2023-01-02  179.691931  234.584483  125.343535  194.803971  1231791
# 2   2023-01-03  109.302199  228.509870  116.551345  203.665900  1483330
# 3   2023-01-04  130.885919  226.767140  103.783303  219.855502  2427768
# 4   2023-01-05  154.428326  203.135891  123.397025  158.149225  2060962
# ..         ...         ...         ...         ...         ...      ...
# 95  2023-04-06  117.269463  229.929199  139.219546  216.909936  1634151
# 96  2023-04-07  106.013569  211.238783   99.401689  182.349945  1102932
# 97  2023-04-08  159.903247  247.106844  149.478497  215.952168  2028177
# 98  2023-04-09  149.705586  202.847022  103.660036  180.713524  1141295
# 99  2023-04-10  150.940283  224.472881  129.625490  200.515839  2360159
#
#     priceChange  Close%Change
# 0     93.749090           NaN
# 1     15.112040     -6.086301
# ...

# %%
max_high = df['High'].max()
min_low = df['Low'].min()
max_close = df['Close'].max()
min_close = df['Close'].min()

# %%
date_mx_high = df.loc[df['High'].idxmax(), 'Date']
date_mn_low = df.loc[df['Low'].idxmin(), 'Date']
date_mx_close = df.loc[df['Close'].idxmax(), 'Date']
date_mn_close = df.loc[df['Close'].idxmin(), 'Date']

# %%
print("🔼 Max High:", max_high, "on", date_mx_high)
print("🔽 Min Low:", min_low, "on", date_mn_low)
print("🔼 Max Close:", max_close, "on", date_mx_close)
print("🔽 Min Close:", min_close, "on", date_mn_close)
# Out:
# 🔼 Max High: 249.9367875851515 on 2023-01-06
# 🔽 Min Low: 90.15559903727906 on 2023-03-14
# 🔼 Max Close: 219.9788566211477 on 2023-03-08
# 🔽 Min Close: 150.59479281140193 on 2023-01-30

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data =df, x ='Date', y= 'Close')
plt.title('Close price trend over time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data =df, x ='Close', bins =30, kde=True)
plt.title('Distribution of Close price')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data =df, y ='Close')
plt.title('Box Plot of Close price')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data =df, x ='Date', y= 'Close%Change')
plt.title('Daily % change in Close price trend over time')
plt.xlabel('Date')
plt.ylabel('% change Close Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data =df, x ='Volume', y= 'Close')
plt.title('Volume vs Close price')
plt.xlabel('Volume')
plt.ylabel('Close Price')
plt.grid(True)
plt.show()
